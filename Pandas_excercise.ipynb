# %%
import pandas as pd
import numpy as np
import random

# %%
age = np.random.randint(low=16,high=80,size=[20,])

# %%
city = np.random.choice(['Mumbai','Chennai','Delhi','Kolkata'],20)

# %%
default = np.random.choice([1,0],20)

# %%
mydata = list(zip(age,city,default))
mydata
# Out:
# [(61, 'Kolkata', 0),
#  (56, 'Kolkata', 1),
#  (31, 'Mumbai', 1),
#  (51, 'Mumbai', 0),
#  (45, 'Delhi', 1),
#  (66, 'Chennai', 1),
#  (57, 'Delhi', 1),
#  (27, 'Chennai', 0),
#  (69, 'Chennai', 1),
#  (20, 'Delhi', 0),
#  (79, 'Kolkata', 1),
#  (64, 'Mumbai', 1),
#  (62, 'Kolkata', 1),
#  (41, 'Kolkata', 1),
#  (23, 'Mumbai', 0),
#  (17, 'Mumbai', 0),
#  (29, 'Kolkata', 1),
#  (74, 'Delhi', 1),
#  (66, 'Mumbai', 1),
#  (51, 'Delhi', 1)]

# %%
df = pd.DataFrame(mydata,columns=['age','city','Others'])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    age     city  Others
# 0   61  Kolkata       0
# 1   56  Kolkata       1
# 2   31   Mumbai       1
# 3   51   Mumbai       0
# 4   45    Delhi       1

# %%
df = pd.DataFrame({"Age":age,"City":city,"Others":default})

# %%
df.head()
# Out:
#    Age     City  Others
# 0   61  Kolkata       0
# 1   56  Kolkata       1
# 2   31   Mumbai       1
# 3   51   Mumbai       0
# 4   45    Delhi       1

# %%
df1 = pd.read_csv('digihack.csv')

# %%
df1
# Out:
#         ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0        1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 1        1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 2        2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 3        2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 4        3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# ...    ...   ...            ...            ...          ...     ...
# 3975  3891  28.0       SALARIED        16,090       16,527   FEMALE
# 3976  3892  27.0       SALARIED        14,000       23,266     MALE
# 3977  3893  43.0  SELF EMPLOYED        21,506       21,506     MALE
# 3978  3894  43.0  SELF EMPLOYED             0            0     MALE
# 3979  3895  42.0  SELF EMPLOYED             0            0     MALE
#
#      Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  \
# ...

# %%
df1.head()
# Out:
#    ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0   1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 1   1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 2   2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 3   2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 4   3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
#
#   Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  ...  \
# 0     CONSTRUCTION        MARRIED             0.0                     96  ...
# 1     CONSTRUCTION        MARRIED             0.0                     96  ...
# 2           OTHERS        MARRIED             0.0                    120  ...
# 3           OTHERS        MARRIED             0.0                    120  ...
# 4           OTHERS        MARRIED             0.0                      0  ...
#
#   ACCOUNT_12  ACCOUNT_13  ACCOUNT_14  ACCOUNT_15  ACCOUNT_16  ACCOUNT_17  \
# ...

# %%
df1.head(10)
# Out:
#    ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0   1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 1   1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 2   2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 3   2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 4   3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# 5   3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# 6   4  26.0       SALARIED        15,488       27,000     MALE
# 7   4  26.0       SALARIED        15,488       27,000     MALE
# 8   5  40.0  SELF EMPLOYED        27,305       27,305     MALE
# 9   5  40.0  SELF EMPLOYED        27,305       27,305     MALE
#
#   Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  ...  \
# 0     CONSTRUCTION        MARRIED             0.0                     96  ...
# 1     CONSTRUCTION        MARRIED             0.0                     96  ...
# ...

# %%
df1.tail(10)
# Out:
#         ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 3970  3886  46.0  SELF EMPLOYED        33,333       33,333     MALE
# 3971  3887  44.0  SELF EMPLOYED        18,333       18,333     MALE
# 3972  3888  25.0       SALARIED        18,000       21,782     MALE
# 3973  3889  35.0  SELF EMPLOYED        34,796       34,796     MALE
# 3974  3890  36.0  SELF EMPLOYED        28,527       28,527     MALE
# 3975  3891  28.0       SALARIED        16,090       16,527   FEMALE
# 3976  3892  27.0       SALARIED        14,000       23,266     MALE
# 3977  3893  43.0  SELF EMPLOYED        21,506       21,506     MALE
# 3978  3894  43.0  SELF EMPLOYED             0            0     MALE
# 3979  3895  42.0  SELF EMPLOYED             0            0     MALE
#
#      Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  \
# 3970           OTHERS        MARRIED           120.0                    120
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_1', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ENQ_8', 'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12',
#        'ACCOUNT_13', 'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17',
#        'ACCOUNT_18', 'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# ID                         int64
# Age                      float64
# Customer_type             object
#  Gross_income             object
#  Net_income               object
# SEX                       object
# Type_of_industry          object
# Marital_Status            object
# Months_in_city           float64
# Months_in_current_job      int64
# Org_Type                  object
# Bank_balance             float64
# Debt_ratio               float64
# Target                     int64
# ENQ_1                      int64
# ENQ_2                      int64
# ENQ_3                      int64
# ENQ_4                      int64
# ENQ_5                      int64
# ENQ_6                      int64
# ENQ_7                      int64
# ENQ_8                      int64
# ACCOUNT_9                  int64
# ACCOUNT_10                 int64
# ACCOUNT_11                 int64
# ACCOUNT_12                 int64
# ACCOUNT_13                 int64
# ACCOUNT_14                 int64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3980 entries, 0 to 3979
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3980 non-null   int64
#  1   Age                    3979 non-null   float64
#  2   Customer_type          3980 non-null   object
#  3    Gross_income          3980 non-null   object
#  4    Net_income            3980 non-null   object
#  5   SEX                    3976 non-null   object
#  6   Type_of_industry       3975 non-null   object
#  7   Marital_Status         3976 non-null   object
#  8   Months_in_city         3976 non-null   float64
#  9   Months_in_current_job  3980 non-null   int64
#  10  Org_Type               3980 non-null   object
#  11  Bank_balance           3344 non-null   float64
#  12  Debt_ratio             3980 non-null   float64
#  13  Target                 3980 non-null   int64
# ...

# %%
df1.shape
# Out:
# (3980, 35)

# %%
new = df1.iloc[2:7,4:8]

# %%
new
# Out:
#    Net_income      SEX Type_of_industry Marital_Status
# 2      30,000   FEMALE           OTHERS        MARRIED
# 3      30,000   FEMALE           OTHERS        MARRIED
# 4    1,88,183     MALE           OTHERS        MARRIED
# 5    1,88,183     MALE           OTHERS        MARRIED
# 6      27,000     MALE           OTHERS        MARRIED

# %%
df1.iloc[3:9,:]
# Out:
#    ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 3   2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 4   3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# 5   3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# 6   4  26.0       SALARIED        15,488       27,000     MALE
# 7   4  26.0       SALARIED        15,488       27,000     MALE
# 8   5  40.0  SELF EMPLOYED        27,305       27,305     MALE
#
#   Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  ...  \
# 3           OTHERS        MARRIED             0.0                    120  ...
# 4           OTHERS        MARRIED             0.0                      0  ...
# 5           OTHERS        MARRIED             0.0                      0  ...
# 6           OTHERS        MARRIED           324.0                      0  ...
# 7           OTHERS        MARRIED           324.0                      0  ...
# ...

# %%
new.iloc[2:5,1:4]
# Out:
#     SEX Type_of_industry Marital_Status
# 4  MALE           OTHERS        MARRIED
# 5  MALE           OTHERS        MARRIED
# 6  MALE           OTHERS        MARRIED

# %%
df1[(df1['SEX']=='FEMALE') & (df1['Age']>30.0)].head()
# Out:
#     ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 2    2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 3    2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 24  13  33.0  SELF EMPLOYED        33,333       33,333   FEMALE
# 25  13  33.0  SELF EMPLOYED        33,333       33,333   FEMALE
# 48  25  34.0  SELF EMPLOYED      2,08,333     2,08,333   FEMALE
#
#    Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  \
# 2            OTHERS        MARRIED             0.0                    120
# 3            OTHERS        MARRIED             0.0                    120
# 24           OTHERS        MARRIED           384.0                     77
# 25           OTHERS        MARRIED           384.0                     77
# 48           OTHERS        MARRIED           300.0                    120
#
#     ... ACCOUNT_12  ACCOUNT_13  ACCOUNT_14  ACCOUNT_15  ACCOUNT_16  \
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_1', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ENQ_8', 'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12',
#        'ACCOUNT_13', 'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17',
#        'ACCOUNT_18', 'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
abc=df1[(df1['Customer_type']== 'SALARIED') & (df1['Months_in_city'] > 300.0)]

# %%
abc.shape
# Out:
# (326, 35)

# %%
abc.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_1', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ENQ_8', 'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12',
#        'ACCOUNT_13', 'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17',
#        'ACCOUNT_18', 'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
abc['Age'].head()
# Out:
# 6     26.0
# 7     26.0
# 40    40.0
# 41    40.0
# 80    29.0
# Name: Age, dtype: float64

# %%
abc[['Customer_type','SEX','Age']].head()
# Out:
#    Customer_type   SEX   Age
# 6       SALARIED  MALE  26.0
# 7       SALARIED  MALE  26.0
# 40      SALARIED  MALE  40.0
# 41      SALARIED  MALE  40.0
# 80      SALARIED  MALE  29.0

# %%
df1.loc[(df1['Customer_type']== 'SALARIED') & (df1['Months_in_city'] > 300.0),['Customer_type','SEX','Age']].head()
# Out:
#    Customer_type   SEX   Age
# 6       SALARIED  MALE  26.0
# 7       SALARIED  MALE  26.0
# 40      SALARIED  MALE  40.0
# 41      SALARIED  MALE  40.0
# 80      SALARIED  MALE  29.0

# %%
df1.loc[~((df1['Customer_type']== 'SALARIED') & (df1['Age'] > 30.0)),['Customer_type','SEX','Age']].head(20)
# Out:
#     Customer_type   SEX   Age
# 0   SELF EMPLOYED  MALE  42.0
# 1   SELF EMPLOYED  MALE  42.0
# 4   SELF EMPLOYED  MALE  36.0
# 5   SELF EMPLOYED  MALE  36.0
# 6        SALARIED  MALE  26.0
# 7        SALARIED  MALE  26.0
# 8   SELF EMPLOYED  MALE  40.0
# 9   SELF EMPLOYED  MALE  40.0
# 12       SALARIED  MALE  26.0
# 13       SALARIED  MALE  26.0
# 14  SELF EMPLOYED  MALE  29.0
# 15  SELF EMPLOYED  MALE  29.0
# 16  SELF EMPLOYED  MALE  33.0
# 17  SELF EMPLOYED  MALE  33.0
# 18  SELF EMPLOYED  MALE  45.0
# 19  SELF EMPLOYED  MALE  45.0
# 20  SELF EMPLOYED  MALE  40.0
# 21  SELF EMPLOYED  MALE  40.0
# 22  SELF EMPLOYED  MALE  45.0
# 23  SELF EMPLOYED  MALE  45.0

# %%
df1=df1.drop(['Target','Debt_ratio'],axis=1)
# Out:
#         ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0        1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 1        1  42.0  SELF EMPLOYED        91,667       91,667     MALE
# 2        2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 3        2  38.0       SALARIED      1,50,000       30,000   FEMALE
# 4        3  36.0  SELF EMPLOYED      1,88,183     1,88,183     MALE
# ...    ...   ...            ...            ...          ...     ...
# 3975  3891  28.0       SALARIED        16,090       16,527   FEMALE
# 3976  3892  27.0       SALARIED        14,000       23,266     MALE
# 3977  3893  43.0  SELF EMPLOYED        21,506       21,506     MALE
# 3978  3894  43.0  SELF EMPLOYED             0            0     MALE
# 3979  3895  42.0  SELF EMPLOYED             0            0     MALE
#
#      Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  \
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_1', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ENQ_8', 'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12',
#        'ACCOUNT_13', 'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17',
#        'ACCOUNT_18', 'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_1', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ENQ_8', 'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12',
#        'ACCOUNT_13', 'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17',
#        'ACCOUNT_18', 'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
del df1['ENQ_1']

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Customer_type', ' Gross_income ', ' Net_income ', 'SEX',
#        'Type_of_industry', 'Marital_Status', 'Months_in_city',
#        'Months_in_current_job', 'Org_Type', 'Bank_balance', 'Debt_ratio',
#        'Target', 'ENQ_2', 'ENQ_3', 'ENQ_4', 'ENQ_5', 'ENQ_6', 'ENQ_7',
#        'ACCOUNT_9', 'ACCOUNT_10', 'ACCOUNT_11', 'ACCOUNT_12', 'ACCOUNT_13',
#        'ACCOUNT_14', 'ACCOUNT_15', 'ACCOUNT_16', 'ACCOUNT_17', 'ACCOUNT_18',
#        'ACCOUNT_19', 'ACCOUNT_20', 'ACCOUNT_21'],
#       dtype='object')

# %%
age=np.random.choice([15,20,30,45,12,'10',15,'34',7,'Missing'],50)
fico=np.random.choice(['100-150','150-200','200-250','250-300'],50)
city=np.random.choice(['Mumbai','Delhi','Chennai','Kolkata'],50)
ID=np.arange(50)
rating=np.random.choice(['Excellent','Good','Bad','Pathetic'],50)
balance=np.random.choice([10000,20000,30000,40000,np.nan,50000,60000],50)
children=np.random.randint(high=5,low=0,size=(50,))

# %%
mydata=pd.DataFrame({'ID':ID,'age':age,'fico':fico,'city':city,'rating':rating,'balance':balance,'children':children})

# %%
mydata.head()
# Out:
#    ID age     fico     city    rating  balance  children
# 0   0   7  250-300    Delhi  Pathetic  50000.0         2
# 1   1  15  150-200  Kolkata      Good  40000.0         1
# 2   2  10  200-250    Delhi  Pathetic  60000.0         0
# 3   3  34  250-300  Chennai       Bad  10000.0         0
# 4   4  12  100-150   Mumbai       Bad  30000.0         2

# %%
mydata.dtypes
# Out:
# ID            int32
# age          object
# fico         object
# city         object
# rating       object
# balance     float64
# children      int32
# dtype: object

# %%
mydata['age']=pd.to_numeric(mydata['age'],errors='coerce')

# %%
mydata['age']
# Out:
# 0      7.0
# 1     15.0
# 2     10.0
# 3     34.0
# 4     12.0
# 5      NaN
# 6     15.0
# 7     15.0
# 8     15.0
# 9     10.0
# 10    30.0
# 11    10.0
# 12    34.0
# 13    20.0
# 14     7.0
# 15    15.0
# 16    10.0
# 17     7.0
# 18    15.0
# 19    34.0
# 20    15.0
# 21    10.0
# 22    20.0
# 23    15.0
# 24    20.0
# 25    20.0
# 26     7.0
# 27     NaN
# 28    30.0
# 29    34.0
# 30     7.0
# 31    10.0
# 32    45.0
# 33    12.0
# 34    12.0
# 35     NaN
# 36    45.0
# 37    10.0
# 38    12.0
# 39    20.0
# 40     7.0
# 41    10.0
# 42     NaN
# 43    15.0
# 44    45.0
# 45    45.0
# 46     7.0
# 47    45.0
# 48    45.0
# 49    12.0
# Name: age, dtype: float64

# %%
mydata['const_var']=100

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100

# %%
mydata['balance_log']=np.log(mydata['balance'])

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var  \
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100
#
#    balance_log
# 0    10.819778
# 1    10.596635
# 2    11.002100
# 3     9.210340
# 4    10.308953

# %%
mydata['age_children_ratio']=mydata['age']/mydata['children']

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var  \
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100
#
#    balance_log  age_children_ratio
# 0    10.819778                 3.5
# 1    10.596635                15.0
# 2    11.002100                 inf
# 3     9.210340                 inf
# 4    10.308953                 6.0

# %%
mydata['age_children_ratio']
# Out:
# 0      3.500000
# 1     15.000000
# 2           inf
# 3           inf
# 4      6.000000
# 5           NaN
# 6           inf
# 7      7.500000
# 8      3.750000
# 9     10.000000
# 10    10.000000
# 11     5.000000
# 12     8.500000
# 13     6.666667
# 14     1.750000
# 15     3.750000
# 16     2.500000
# 17     3.500000
# 18     7.500000
# 19    11.333333
# 20          inf
# 21     5.000000
# 22    10.000000
# 23     7.500000
# 24          inf
# 25    20.000000
# 26     3.500000
# 27          NaN
# 28    10.000000
# 29    17.000000
# 30     3.500000
# 31          inf
# 32    45.000000
# 33     4.000000
# 34    12.000000
# 35          NaN
# 36    11.250000
# 37     2.500000
# 38     4.000000
# 39    10.000000
# 40          inf
# 41    10.000000
# 42          NaN
# 43     5.000000
# 44    15.000000
# 45    45.000000
# 46          inf
# 47    11.250000
# 48    22.500000
# 49     6.000000
# Name: age_children_ratio, dtype: float64

# %%
mydata['age'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: age, dtype: bool

# %%
mydata['age'].isnull().sum()
# Out:
# 4

# %%
mydata.loc[mydata['age'].isnull(),'age']
# Out:
# 5    NaN
# 27   NaN
# 35   NaN
# 42   NaN
# Name: age, dtype: float64

# %%
mydata.loc[mydata['age'].isnull(),'age'] = np.mean(mydata['age'])

# %%
mydata['age']
# Out:
# 0      7.000000
# 1     15.000000
# 2     10.000000
# 3     34.000000
# 4     12.000000
# 5     19.347826
# 6     15.000000
# 7     15.000000
# 8     15.000000
# 9     10.000000
# 10    30.000000
# 11    10.000000
# 12    34.000000
# 13    20.000000
# 14     7.000000
# 15    15.000000
# 16    10.000000
# 17     7.000000
# 18    15.000000
# 19    34.000000
# 20    15.000000
# 21    10.000000
# 22    20.000000
# 23    15.000000
# 24    20.000000
# 25    20.000000
# 26     7.000000
# 27    19.347826
# 28    30.000000
# 29    34.000000
# 30     7.000000
# 31    10.000000
# 32    45.000000
# 33    12.000000
# 34    12.000000
# 35    19.347826
# 36    45.000000
# 37    10.000000
# 38    12.000000
# 39    20.000000
# 40     7.000000
# 41    10.000000
# 42    19.347826
# 43    15.000000
# 44    45.000000
# 45    45.000000
# 46     7.000000
# 47    45.000000
# 48    45.000000
# 49    12.000000
# Name: age, dtype: float64

# %%
mydata['age_children_ratio']=mydata['age']/mydata['children']

# %%
mydata['age_children_ratio']
# Out:
# 0      3.500000
# 1     15.000000
# 2           inf
# 3           inf
# 4      6.000000
# 5      9.673913
# 6           inf
# 7      7.500000
# 8      3.750000
# 9     10.000000
# 10    10.000000
# 11     5.000000
# 12     8.500000
# 13     6.666667
# 14     1.750000
# 15     3.750000
# 16     2.500000
# 17     3.500000
# 18     7.500000
# 19    11.333333
# 20          inf
# 21     5.000000
# 22    10.000000
# 23     7.500000
# 24          inf
# 25    20.000000
# 26     3.500000
# 27     9.673913
# 28    10.000000
# 29    17.000000
# 30     3.500000
# 31          inf
# 32    45.000000
# 33     4.000000
# 34    12.000000
# 35          inf
# 36    11.250000
# 37     2.500000
# 38     4.000000
# 39    10.000000
# 40          inf
# 41    10.000000
# 42     6.449275
# 43     5.000000
# 44    15.000000
# 45    45.000000
# 46          inf
# 47    11.250000
# 48    22.500000
# 49     6.000000
# Name: age_children_ratio, dtype: float64

# %%
mydata['rating_score']=np.where(mydata['rating'].isin(['Good','Excellent']),1,0)

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var  \
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100
#
#    balance_log  age_children_ratio  rating_score
# 0    10.819778                 3.5             0
# 1    10.596635                15.0             1
# 2    11.002100                 inf             0
# 3     9.210340                 inf             0
# 4    10.308953                 6.0             0

# %%
mydata.loc[mydata['rating']=='Pathetic','rating_score']=-1

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var  \
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100
#
#    balance_log  age_children_ratio  rating_score
# 0    10.819778                 3.5            -1
# 1    10.596635                15.0             1
# 2    11.002100                 inf            -1
# 3     9.210340                 inf             0
# 4    10.308953                 6.0             0

# %%
mydata['fico'].split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e967df8ee134> in <module>
# ----> 1 mydata['fico'].split()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
mydata['fico'].str.split('-').head()
# Out:
# 0    [250, 300]
# 1    [150, 200]
# 2    [200, 250]
# 3    [250, 300]
# 4    [100, 150]
# Name: fico, dtype: object

# %%
mydata['fico'].str.split('-',expand=True).head()
# Out:
#      0    1
# 0  250  300
# 1  150  200
# 2  200  250
# 3  250  300
# 4  100  150

# %%
k=mydata['fico'].str.split('-',expand=True).astype(float)

# %%
k[0].head()
# Out:
# 0    250.0
# 1    150.0
# 2    200.0
# 3    250.0
# 4    100.0
# Name: 0, dtype: float64

# %%
k[1].head()
# Out:
# 0    300.0
# 1    200.0
# 2    250.0
# 3    300.0
# 4    150.0
# Name: 1, dtype: float64

# %%
mydata['f1'],mydata['f2']=k[0],k[1]

# %%
mydata.head()
# Out:
#    ID   age     fico     city    rating  balance  children  const_var  \
# 0   0   7.0  250-300    Delhi  Pathetic  50000.0         2        100
# 1   1  15.0  150-200  Kolkata      Good  40000.0         1        100
# 2   2  10.0  200-250    Delhi  Pathetic  60000.0         0        100
# 3   3  34.0  250-300  Chennai       Bad  10000.0         0        100
# 4   4  12.0  100-150   Mumbai       Bad  30000.0         2        100
#
#    balance_log  age_children_ratio  rating_score     f1     f2
# 0    10.819778                 3.5            -1  250.0  300.0
# 1    10.596635                15.0             1  150.0  200.0
# 2    11.002100                 inf            -1  200.0  250.0
# 3     9.210340                 inf             0  250.0  300.0
# 4    10.308953                 6.0             0  100.0  150.0

# %%
del mydata['fico']

# %%
mydata.head()
# Out:
#    ID   age     city    rating  balance  children  const_var  balance_log  \
# 0   0   7.0    Delhi  Pathetic  50000.0         2        100    10.819778
# 1   1  15.0  Kolkata      Good  40000.0         1        100    10.596635
# 2   2  10.0    Delhi  Pathetic  60000.0         0        100    11.002100
# 3   3  34.0  Chennai       Bad  10000.0         0        100     9.210340
# 4   4  12.0   Mumbai       Bad  30000.0         2        100    10.308953
#
#    age_children_ratio  rating_score     f1     f2
# 0                 3.5            -1  250.0  300.0
# 1                15.0             1  150.0  200.0
# 2                 inf            -1  200.0  250.0
# 3                 inf             0  250.0  300.0
# 4                 6.0             0  100.0  150.0

# %%
mydata['city'].unique()
# Out:
# array(['Delhi', 'Kolkata', 'Chennai', 'Mumbai'], dtype=object)

# %%
mydata['city'].nunique()
# Out:
# 4

# %%
mydata['city_mumbai']=np.where(mydata['city']=='Mumbai',1,0)

# %%
mydata.head()
# Out:
#    ID   age     city    rating  balance  children  const_var  balance_log  \
# 0   0   7.0    Delhi  Pathetic  50000.0         2        100    10.819778
# 1   1  15.0  Kolkata      Good  40000.0         1        100    10.596635
# 2   2  10.0    Delhi  Pathetic  60000.0         0        100    11.002100
# 3   3  34.0  Chennai       Bad  10000.0         0        100     9.210340
# 4   4  12.0   Mumbai       Bad  30000.0         2        100    10.308953
#
#    age_children_ratio  rating_score     f1     f2  city_mumbai
# 0                 3.5            -1  250.0  300.0            0
# 1                15.0             1  150.0  200.0            0
# 2                 inf            -1  200.0  250.0            0
# 3                 inf             0  250.0  300.0            0
# 4                 6.0             0  100.0  150.0            1

# %%
mydata['city_chennai']=(mydata['city']=='Chennai').astype(int)

# %%
mydata.head()
# Out:
#    ID   age     city    rating  balance  children  const_var  balance_log  \
# 0   0   7.0    Delhi  Pathetic  50000.0         2        100    10.819778
# 1   1  15.0  Kolkata      Good  40000.0         1        100    10.596635
# 2   2  10.0    Delhi  Pathetic  60000.0         0        100    11.002100
# 3   3  34.0  Chennai       Bad  10000.0         0        100     9.210340
# 4   4  12.0   Mumbai       Bad  30000.0         2        100    10.308953
#
#    age_children_ratio  rating_score     f1     f2  city_mumbai  city_chennai
# 0                 3.5            -1  250.0  300.0            0             0
# 1                15.0             1  150.0  200.0            0             0
# 2                 inf            -1  200.0  250.0            0             0
# 3                 inf             0  250.0  300.0            0             1
# 4                 6.0             0  100.0  150.0            1             0

# %%
mydata['city_kolkata']=np.where(mydata['city']=='Kolkata',1,0)

# %%
mydata.head()
# Out:
#    ID   age     city    rating  balance  children  const_var  balance_log  \
# 0   0   7.0    Delhi  Pathetic  50000.0         2        100    10.819778
# 1   1  15.0  Kolkata      Good  40000.0         1        100    10.596635
# 2   2  10.0    Delhi  Pathetic  60000.0         0        100    11.002100
# 3   3  34.0  Chennai       Bad  10000.0         0        100     9.210340
# 4   4  12.0   Mumbai       Bad  30000.0         2        100    10.308953
#
#    age_children_ratio  rating_score     f1     f2  city_mumbai  city_chennai  \
# 0                 3.5            -1  250.0  300.0            0             0
# 1                15.0             1  150.0  200.0            0             0
# 2                 inf            -1  200.0  250.0            0             0
# 3                 inf             0  250.0  300.0            0             1
# 4                 6.0             0  100.0  150.0            1             0
#
#    city_kolkata
# 0             0
# 1             1
# ...

# %%
del mydata['city']

# %%
mydata.head()
# Out:
#    ID   age    rating  balance  children  const_var  balance_log  \
# 0   0   7.0  Pathetic  50000.0         2        100    10.819778
# 1   1  15.0      Good  40000.0         1        100    10.596635
# 2   2  10.0  Pathetic  60000.0         0        100    11.002100
# 3   3  34.0       Bad  10000.0         0        100     9.210340
# 4   4  12.0       Bad  30000.0         2        100    10.308953
#
#    age_children_ratio  rating_score     f1     f2  city_mumbai  city_chennai  \
# 0                 3.5            -1  250.0  300.0            0             0
# 1                15.0             1  150.0  200.0            0             0
# 2                 inf            -1  200.0  250.0            0             0
# 3                 inf             0  250.0  300.0            0             1
# 4                 6.0             0  100.0  150.0            1             0
#
#    city_kolkata
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
mydata['rating'].unique()
# Out:
# array(['Pathetic', 'Good', 'Bad', 'Excellent'], dtype=object)

# %%
mydata['rating'].nunique()
# Out:
# 4

# %%
dummy=pd.get_dummies(mydata['rating'],drop_first=True,prefix='rating')

# %%
dummy.head()
# Out:
#    rating_Excellent  rating_Good  rating_Pathetic
# 0                 0            0                1
# 1                 0            1                0
# 2                 0            0                1
# 3                 0            0                0
# 4                 0            0                0

# %%
mydata=pd.concat([mydata,dummy],axis=1)

# %%
mydata.head()
# Out:
#    ID   age  balance  children  const_var  balance_log  age_children_ratio  \
# 0   0   7.0  50000.0         2        100    10.819778                 3.5
# 1   1  15.0  40000.0         1        100    10.596635                15.0
# 2   2  10.0  60000.0         0        100    11.002100                 inf
# 3   3  34.0  10000.0         0        100     9.210340                 inf
# 4   4  12.0  30000.0         2        100    10.308953                 6.0
#
#    rating_score     f1     f2  city_mumbai  city_chennai  city_kolkata  \
# 0            -1  250.0  300.0            0             0             0
# 1             1  150.0  200.0            0             0             1
# 2            -1  200.0  250.0            0             0             0
# 3             0  250.0  300.0            0             1             0
# 4             0  100.0  150.0            1             0             0
#
#    rating_Excellent  rating_Good  rating_Pathetic
# ...

# %%
del mydata['rating']

# %%
df=pd.DataFrame(np.random.randint(2,8,(20,4)),columns=['A','B','C','D'])

# %%
df
# Out:
#     A  B  C  D
# 0   5  4  3  5
# 1   7  7  3  2
# 2   2  2  2  2
# 3   7  5  2  5
# 4   3  6  3  4
# 5   2  5  2  7
# 6   2  5  6  3
# 7   2  6  7  5
# 8   4  2  6  7
# 9   2  2  6  5
# 10  2  6  4  3
# 11  7  6  6  2
# 12  6  5  3  6
# 13  4  7  5  3
# 14  6  4  6  2
# 15  5  2  3  7
# 16  2  5  5  6
# 17  6  7  4  5
# 18  3  6  4  5
# 19  5  7  4  7

# %%
df.sort_values('A').head()
# Out:
#     A  B  C  D
# 9   2  2  6  5
# 16  2  5  5  6
# 2   2  2  2  2
# 5   2  5  2  7
# 6   2  5  6  3

# %%
df
# Out:
#     A  B  C  D
# 0   5  4  3  5
# 1   7  7  3  2
# 2   2  2  2  2
# 3   7  5  2  5
# 4   3  6  3  4
# 5   2  5  2  7
# 6   2  5  6  3
# 7   2  6  7  5
# 8   4  2  6  7
# 9   2  2  6  5
# 10  2  6  4  3
# 11  7  6  6  2
# 12  6  5  3  6
# 13  4  7  5  3
# 14  6  4  6  2
# 15  5  2  3  7
# 16  2  5  5  6
# 17  6  7  4  5
# 18  3  6  4  5
# 19  5  7  4  7

# %%
df=df.sort_values('A')

# %%
df.sort_values('A',inplace=True)

# %%
df.sort_values('A',inplace=True,ascending=False)

# %%
df
# Out:
#     A  B  C  D
# 1   7  7  3  2
# 3   7  5  2  5
# 11  7  6  6  2
# 12  6  5  3  6
# 17  6  7  4  5
# 14  6  4  6  2
# 15  5  2  3  7
# 19  5  7  4  7
# 0   5  4  3  5
# 8   4  2  6  7
# 13  4  7  5  3
# 18  3  6  4  5
# 4   3  6  3  4
# 16  2  5  5  6
# 10  2  6  4  3
# 7   2  6  7  5
# 6   2  5  6  3
# 5   2  5  2  7
# 2   2  2  2  2
# 9   2  2  6  5

# %%
df.sort_values(['B','C'],ascending=[False,True])
# Out:
#     A  B  C  D
# 1   7  7  3  2
# 17  6  7  4  5
# 19  5  7  4  7
# 13  4  7  5  3
# 4   3  6  3  4
# 18  3  6  4  5
# 10  2  6  4  3
# 11  7  6  6  2
# 7   2  6  7  5
# 3   7  5  2  5
# 5   2  5  2  7
# 12  6  5  3  6
# 16  2  5  5  6
# 6   2  5  6  3
# 0   5  4  3  5
# 14  6  4  6  2
# 2   2  2  2  2
# 15  5  2  3  7
# 8   4  2  6  7
# 9   2  2  6  5

# %%
import pandas as pd

# %%
df1=pd.DataFrame([['a',1],['b',2]],columns=["letter","number"])
df2=pd.DataFrame([['a',1,'cat'],['b',2,'dog']],columns=["letter","number","animal"])
pd.concat([df1,df2],axis=0)
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      a       1    cat
# 1      b       2    dog

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 2      a       1    cat
# 3      b       2    dog

# %%
df3=pd.DataFrame([['tiger','Teo'],['lion','Leo'],['Dog','Tommy']],columns=["Animal","Name"])

# %%
pd.concat([df1,df3],axis=1)
# Out:
#   letter  number Animal   Name
# 0      a     1.0  tiger    Teo
# 1      b     2.0   lion    Leo
# 2    NaN     NaN    Dog  Tommy

# %%
df1=pd.DataFrame({'cust_id':[1,2,3,4,5],'product':['radio','pen','pencil','eraser','mobile']})
df2=pd.DataFrame({'cust_id':[3,4,5,6,7],'state':['MH','MH','GJ','MP','UP']})

# %%
df1
# Out:
#    cust_id product
# 0        1   radio
# 1        2     pen
# 2        3  pencil
# 3        4  eraser
# 4        5  mobile

# %%
df2
# Out:
#    cust_id state
# 0        3    MH
# 1        4    MH
# 2        5    GJ
# 3        6    MP
# 4        7    UP

# %%
pd.merge(df1,df2,on=['cust_id'],how='right')
# Out:
#    cust_id product state
# 0        3  pencil    MH
# 1        4  eraser    MH
# 2        5  mobile    GJ
# 3        6     NaN    MP
# 4        7     NaN    UP

# %%
bank = pd.read_csv('bank-full.csv')

# %%
bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
bank.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
bank.nunique()
# Out:
# age            77
# job            12
# marital         3
# education       4
# default         2
# balance      7168
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1573
# campaign       48
# pdays         559
# previous       41
# poutcome        4
# Target          2
# dtype: int64

# %%
bank['age'].describe()
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
bank['job'].describe()
# Out:
# count           45211
# unique             12
# top       blue-collar
# freq             9732
# Name: job, dtype: object

# %%
bank['job']
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: job, Length: 45211, dtype: object

# %%
bank['age'].mean(),bank['age'].median()
# Out:
# (40.93621021432837, 39.0)

# %%
bank['job'].value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
k=bank['job'].value_counts()

# %%
k.index
# Out:
# Index(['blue-collar', 'management', 'technician', 'admin.', 'services',
#        'retired', 'self-employed', 'entrepreneur', 'unemployed', 'housemaid',
#        'student', 'unknown'],
#       dtype='object')

# %%
k.values
# Out:
# array([9732, 9458, 7597, 5171, 4154, 2264, 1579, 1487, 1303, 1240,  938,
#         288], dtype=int64)

# %%
k[-1]
# Out:
# 288

# %%
k.index[0]
# Out:
# 'blue-collar'

# %%
k.index[k.values>1500]
# Out:
# Index(['blue-collar', 'management', 'technician', 'admin.', 'services',
#        'retired', 'self-employed'],
#       dtype='object')

# %%
k.index[k>1500]
# Out:
# Index(['blue-collar', 'management', 'technician', 'admin.', 'services',
#        'retired', 'self-employed'],
#       dtype='object')

# %%
pd.crosstab(bank['housing'],bank['default'])
# Out:
# default     no  yes
# housing
# no       19701  380
# yes      24695  435

# %%
cat_vars=bank.select_dtypes('object').columns

# %%
cat_vars
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'Target'],
#       dtype='object')

# %%
for col in cat_vars:
    print(bank[col].value_counts())
    print('!!!!!')
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# !!!!!
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# !!!!!
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# !!!!!
# no     44396
# yes      815
# Name: default, dtype: int64
# !!!!!
# yes    25130
# no     20081
# Name: housing, dtype: int64
# !!!!!
# no     37967
# yes     7244
# Name: loan, dtype: int64
# !!!!!
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# !!!!!
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# ...

# %%
bank.groupby(['default'])['age'].mean()#select avg(age) from bank group by default
# Out:
# default
# no     40.961934
# yes    39.534969
# Name: age, dtype: float64

# %%
bank.groupby(['default','loan']).median()
# Out:
#                age  balance   day  duration  campaign  pdays  previous
# default loan
# no      no    39.0    509.0  16.0     181.0       2.0   -1.0       0.0
#         yes   39.0    284.0  17.0     175.0       2.0   -1.0       0.0
# yes     no    38.0     -3.5  17.0     178.5       2.0   -1.0       0.0
#         yes   39.0    -21.0  18.0     163.0       2.0   -1.0       0.0

# %%
import numpy as np
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2000",periods=1000))
print(ts)
# Out:
# 2000-01-01   -0.121228
# 2000-01-02    0.496154
# 2000-01-03   -0.087525
# 2000-01-04    1.027189
# 2000-01-05   -1.160261
#                 ...
# 2002-09-22   -0.657377
# 2002-09-23   -0.878473
# 2002-09-24    0.932659
# 2002-09-25    1.287140
# 2002-09-26    0.221978
# Freq: D, Length: 1000, dtype: float64

# %%
ts=ts.cumsum()
ts
# Out:
# 2000-01-01    -0.121228
# 2000-01-02     0.374925
# 2000-01-03     0.287400
# 2000-01-04     1.314590
# 2000-01-05     0.154329
#                 ...
# 2002-09-22   -19.846515
# 2002-09-23   -20.724988
# 2002-09-24   -19.792329
# 2002-09-25   -18.505188
# 2002-09-26   -18.283211
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.016033  1.740898 -1.109188 -1.009759
# 2000-01-02 -1.021259 -1.272047  0.314083  0.277582
# 2000-01-03 -1.702375  0.241657  1.369991 -0.360853
# 2000-01-04  0.406996 -1.759019  0.283429  0.865865
# 2000-01-05 -0.544915  1.520244 -0.097909 -1.356237
# ...              ...       ...       ...       ...
# 2002-09-22  1.140439  0.036376  0.708131 -0.256841
# 2002-09-23  0.559087 -1.578758 -0.872338 -1.680401
# 2002-09-24  0.716394 -0.868993 -0.086028 -0.077665
# 2002-09-25 -1.936006 -1.550827 -2.215397  0.008105
# 2002-09-26  1.641547  2.114647 -0.210567  0.575566
#
# [1000 rows x 4 columns]

# %%
list("Age123")
# Out:
# ['A', 'g', 'e', '1', '2', '3']

# %%
df=df.cumsum()

# %%
#import matplotlib.pyplot as plt

# %%
#plt.figure()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()

# %%
df3
# Out:
#              B         C
# 0     0.900432  0.406932
# 1    -0.383944 -0.400703
# 2    -1.401159  0.704467
# 3    -1.763805  2.045095
# 4    -4.375826  0.891441
# ..         ...       ...
# 995  17.927514  0.377326
# 996  16.755145  1.486057
# 997  15.796822 -0.473271
# 998  15.806052 -0.506304
# 999  15.805449 -0.976076
#
# [1000 rows x 2 columns]

# %%
df3["A"] = pd.Series(list(range(len(df))))

# %%
pd.Series(list(range(len(df))))
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Length: 1000, dtype: int64

# %%
df3
# Out:
#              B         C    A
# 0     0.900432  0.406932    0
# 1    -0.383944 -0.400703    1
# 2    -1.401159  0.704467    2
# 3    -1.763805  2.045095    3
# 4    -4.375826  0.891441    4
# ..         ...       ...  ...
# 995  17.927514  0.377326  995
# 996  16.755145  1.486057  996
# 997  15.796822 -0.473271  997
# 998  15.806052 -0.506304  998
# 999  15.805449 -0.976076  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A",y="B")
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df.iloc[5].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.iloc[1]
# Out:
# A   -1.037292
# B    0.468851
# C   -0.795105
# D   -0.732178
# Name: 2000-01-02 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B          C          D
# 2000-01-01 -0.016033  1.740898  -1.109188  -1.009759
# 2000-01-02 -1.037292  0.468851  -0.795105  -0.732178
# 2000-01-03 -2.739666  0.710508   0.574886  -1.093031
# 2000-01-04 -2.332670 -1.048511   0.858315  -0.227166
# 2000-01-05 -2.877585  0.471733   0.760406  -1.583403
# ...              ...       ...        ...        ...
# 2002-09-22 -4.737666  1.907032  20.077164  49.367328
# 2002-09-23 -4.178579  0.328274  19.204826  47.686927
# 2002-09-24 -3.462186 -0.540719  19.118798  47.609261
# 2002-09-25 -5.398192 -2.091546  16.903402  47.617366
# 2002-09-26 -3.756645  0.023101  16.692835  48.192932
#
# [1000 rows x 4 columns]

# %%
df2=pd.DataFrame(np.random.rand(10,4),columns=["a","b","c","d"])
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df4=pd.DataFrame({"a":np.random.randn(1000)+1,"b":np.random.randn(1000),"c":np.random.randn(1000)-1},columns=["a","b","c"])
df4.plot.hist(alpha=0.3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4
# Out:
#             a         b         c
# 0    0.850613  1.550069 -0.961809
# 1    0.280711  0.925221 -1.836546
# 2    1.297164 -0.477251 -1.354544
# 3    1.992839 -0.790695 -0.575134
# 4    0.963948  1.719043 -0.810863
# ..        ...       ...       ...
# 995  1.185771 -0.827359 -0.774094
# 996  1.734228  0.520232 -0.784706
# 997  0.514445 -1.839901 -3.154453
# 998  1.144022 -0.693689 -1.048588
# 999  2.359124 -1.518510 -2.274536
#
# [1000 rows x 3 columns]

# %%
df4.plot.hist(stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4["a"].plot.hist(orientation="horizontal",cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df4.diff().hist(color="k",alpha=0.5,bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
data=pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0,4,1000),figsize=(6,4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %%
np.random.randint(0,4,1000)
# Out:
# array([0, 3, 0, 2, 3, 0, 1, 0, 2, 3, 1, 1, 2, 3, 0, 2, 1, 2, 3, 1, 3, 2,
#        0, 0, 3, 2, 0, 2, 0, 2, 0, 2, 2, 1, 2, 1, 3, 0, 1, 3, 3, 3, 2, 0,
#        3, 2, 1, 3, 3, 0, 2, 3, 0, 0, 3, 3, 3, 1, 2, 1, 3, 3, 1, 1, 2, 3,
#        2, 1, 1, 3, 0, 1, 1, 0, 3, 3, 1, 1, 1, 2, 2, 2, 2, 3, 0, 2, 3, 1,
#        3, 1, 1, 2, 0, 3, 2, 0, 2, 2, 3, 2, 3, 3, 2, 3, 2, 2, 2, 2, 0, 3,
#        0, 1, 2, 1, 0, 0, 2, 1, 0, 3, 3, 0, 3, 1, 2, 1, 0, 0, 1, 2, 3, 0,
#        3, 0, 0, 0, 2, 2, 0, 3, 0, 1, 2, 0, 3, 3, 0, 2, 0, 0, 1, 2, 1, 1,
#        3, 2, 3, 1, 3, 3, 1, 3, 0, 1, 1, 1, 1, 2, 3, 2, 1, 3, 1, 0, 3, 0,
#        1, 2, 2, 1, 0, 2, 1, 1, 2, 2, 2, 1, 3, 1, 3, 2, 2, 0, 3, 3, 2, 3,
#        0, 3, 2, 1, 2, 2, 0, 2, 1, 1, 2, 1, 2, 1, 0, 1, 2, 0, 3, 3, 1, 2,
#        2, 2, 0, 1, 0, 3, 3, 0, 3, 1, 3, 3, 1, 1, 2, 2, 0, 2, 1, 0, 2, 1,
#        3, 2, 1, 1, 1, 2, 0, 3, 3, 3, 1, 1, 1, 0, 0, 2, 0, 0, 3, 2, 0, 3,
#        2, 3, 1, 0, 3, 0, 2, 0, 0, 2, 3, 3, 2, 1, 2, 3, 3, 3, 0, 1, 0, 1,
# ...

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

# %%
df.plot.box();

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.524591  0.659938  0.777618  0.373279  0.108248
# 1  0.578495  0.422713  0.766586  0.829010  0.054215
# 2  0.126130  0.338878  0.530224  0.426672  0.241846
# 3  0.800414  0.355764  0.288285  0.398802  0.891536
# 4  0.573296  0.419737  0.482022  0.177284  0.665509
# 5  0.593233  0.356312  0.167802  0.931640  0.741099
# 6  0.994569  0.850697  0.600720  0.846117  0.026797
# 7  0.140634  0.371991  0.359825  0.550516  0.357071
# 8  0.824649  0.263559  0.553468  0.305107  0.037231
# 9  0.320952  0.593929  0.130642  0.803062  0.724035

# %%
color = {"boxes": "DarkGreen","whiskers": "DarkOrange",  "medians":
"DarkBlue", "caps": "Gray"}

# %%
df.plot.box(color=color, sym="r+")
# Out:
# <AxesSubplot:>

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8]);

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])

# %%
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])

# %%
bp = df.boxplot(by="X")

# %%
df
# Out:
#        Col1      Col2  X
# 0  0.247617  0.448438  A
# 1  0.262698  0.609448  A
# 2  0.027239  0.295788  A
# 3  0.871097  0.889679  A
# 4  0.769812  0.104823  A
# 5  0.004658  0.502444  B
# 6  0.401178  0.382501  B
# 7  0.571741  0.518331  B
# 8  0.113061  0.564662  B
# 9  0.945374  0.277784  B

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

# %%
df.plot.area();

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])

# %%
df["species"] = pd.Categorical(["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] *
10 )

# %%
df
# Out:
#            a         b         c         d     species
# 0   0.833204  0.755280  0.212245  0.681081      setosa
# 1   0.048110  0.968316  0.225285  0.670522      setosa
# 2   0.686348  0.300255  0.872973  0.238831      setosa
# 3   0.152568  0.396532  0.365431  0.003369      setosa
# 4   0.258410  0.327912  0.449638  0.445028      setosa
# 5   0.672353  0.280811  0.409291  0.850346      setosa
# 6   0.773334  0.721964  0.780477  0.714546      setosa
# 7   0.404178  0.471200  0.704076  0.138445      setosa
# 8   0.933520  0.597285  0.885940  0.153979      setosa
# 9   0.478863  0.490427  0.993519  0.438063      setosa
# 10  0.683622  0.366128  0.947819  0.795336      setosa
# 11  0.216897  0.097323  0.654487  0.914934      setosa
# 12  0.968547  0.047871  0.228823  0.919448      setosa
# 13  0.199890  0.592228  0.158128  0.810415      setosa
# 14  0.385933  0.871697  0.683286  0.942111      setosa
# 15  0.691353  0.950096  0.970062  0.696842      setosa
# ...

# %%
df.plot.scatter(x="a", y="b")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")

# %%
ax2 =df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2")

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])

# %%
df["b"] = df["b"] + np.arange(1000)

# %%
df
# Out:
#             a           b
# 0    1.188497   -0.756038
# 1   -0.911419    0.838214
# 2    0.339501    2.031493
# 3   -0.345118    4.733795
# 4    1.110318    2.843334
# ..        ...         ...
# 995  1.013792  995.028263
# 996  1.970844  996.313601
# 997  2.530165  998.925537
# 998 -0.963841  998.632670
# 999  0.354586  999.233379
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x="a", y="b", gridsize=25);

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

# %%
series
# Out:
# a    1.022845
# b    2.809618
# c    0.762056
# d    0.191624
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x","y"]  )

# %%
df.plot.pie(subplots=True, figsize=(8, 4));

# %%
df
# Out:
#           x         y
# a  1.857748  0.271952
# b  1.427874  1.611225
# c  0.475909  2.285401
# d  2.444797  1.838551

# %%
series.plot.pie(labels=["AA", "BB", "CC", "DD"], colors=["r", "g", "b", "c"], autopct="%.2f", fontsize=20, figsize=(6, 6) )
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series = pd.Series([0.1] * 4, index=["a", "b", "c", "d"], name="series2")

# %%
series
# Out:
# a    0.1
# b    0.1
# c    0.1
# d    0.1
# Name: series2, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))
# Out:
# C:\Users\Ekta Shah\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='series2'>

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde");
