# %%
import numpy as np
import pandas as pd

# %%
# importing the data
file = r'~/Downloads/creditcard_sampledata_2.csv'

# %%
data = pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0        V1        V2        V3        V4        V5        V6  \
# 0      221547 -1.191668  0.428409  1.640028 -1.848859 -0.870903 -0.204849
# 1      184524  1.966614 -0.450087 -1.228586  0.142873 -0.150627 -0.543590
# 2       91201  1.528452 -1.296191 -0.890677 -2.504028  0.803202  3.350793
# 3       26115 -0.774614  1.100916  0.679080  1.034016  0.168633  0.874582
# 4      201292 -1.075860  1.361160  1.496972  2.242604  1.314751  0.272787
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -0.385675  0.352793 -1.098301  ...  0.507173  1.292565 -0.467752  1.244887
# 1 -0.076217 -0.108390  0.973310  ...  0.124055  0.564916 -0.039331 -0.283904
# 2 -1.633016  0.815350 -1.884692  ... -0.412088 -1.017485  0.129566  0.948048
# 3  0.209454  0.770550 -0.558106  ...  0.011158  0.146017 -0.130401 -0.848815
# 4  1.005246  0.132932 -1.558317  ...  0.254485  0.530692 -0.651119  0.626389
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.697707  0.059375 -0.319964 -0.017444   27.44      0
# 1  0.186400  0.192932 -0.039155 -0.071314   35.95      0
# 2  0.287826 -0.396592  0.042997  0.025853   28.40      0
# 3  0.005698 -0.183295  0.282940  0.123856   43.20      0
# 4  1.040212  0.249501 -0.146745  0.029714   10.59      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (7300, 31)

# %%
a = data['Class'].value_counts()
a
# Out:
# 0    7000
# 1     300
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from pprint import pprint as pp
import csv
from pathlib import Path
import seaborn as sns
from itertools import product
import string

# import nltk
# from nltk.corpus import stopwords
# from nltk.stem.wordnet import WordNetLemmatizer

from imblearn.over_sampling import SMOTE
# from imblearn.over_sampling import BorderlineSMOTE
# from imblearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score, classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.metrics import homogeneity_score, silhouette_score
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import MiniBatchKMeans, DBSCAN

# pip install -U imbalanced-learn

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Define the resampling method
method = SMOTE()

# %%
# prep data function
def prep_data(df:pd.DataFrame):
    X = df.iloc[:,1:30].values
    y = df.Class.values
    return (X,y)

# %%
X,y = prep_data(data)

# %%
X.shape
# Out:
# (7300, 29)

# %%
# Create the resampled feature set
X_resampled, y_resampled = method.fit_resample(X,y)

# %%
def plot_graph(x:np.ndarray, y:np.ndarray):
    plt.scatter(x[y==0,0],x[y==0,2], label='Class 0')
    plt.scatter(x[y==1,0],x[y==1,2], label='Class 1', c='r')
    plt.legend()
    return plt.show()

# %%
plot_graph(X,y)

# %%
plot_graph(X_resampled,y_resampled)

# %%
X.shape
# Out:
# (7300, 29)

# %%
y.shape
# Out:
# (7300,)

# %%
X_resampled.shape
# Out:
# (14000, 29)

# %%
y_resampled.shape
# Out:
# (14000,)

# %%
# correlation matrix of numeric colums
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_421da_row0_col0, #T_421da_row1_col1, #T_421da_row2_col2, #T_421da_row3_col3, #T_421da_row4_col4, #T_421da_row5_col5, #T_421da_row6_col6, #T_421da_row7_col7, #T_421da_row8_col8, #T_421da_row9_col9, #T_421da_row10_col10, #T_421da_row11_col11, #T_421da_row12_col12, #T_421da_row13_col13, #T_421da_row14_col14, #T_421da_row15_col15, #T_421da_row16_col16, #T_421da_row17_col17, #T_421da_row18_col18, #T_421da_row19_col19, #T_421da_row20_col20, #T_421da_row21_col21, #T_421da_row22_col22, #T_421da_row23_col23, #T_421da_row24_col24, #T_421da_row25_col25, #T_421da_row26_col26, #T_421da_row27_col27, #T_421da_row28_col28, #T_421da_row29_col29, #T_421da_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_421da_row0_col1, #T_421da_row8_col4, #T_421da_row13_col17, #T_421da_row22_col12 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_421da_row0_col2, #T_421da_row3_col6, #T_421da_row4_col19, #T_421da_row16_col6, #T_421da_row27_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_421da_row0_col3, #T_421da_row0_col4, #T_421da_row6_col2, #T_421da_row19_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_421da_row0_col5, #T_421da_row25_col10, #T_421da_row27_col7, #T_421da_row29_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_421da_row0_col6, #T_421da_row2_col15, #T_421da_row4_col23, #T_421da_row5_col29, #T_421da_row9_col23, #T_421da_row11_col28, #T_421da_row13_col0, #T_421da_row13_col23, #T_421da_row17_col22, #T_421da_row20_col6, #T_421da_row28_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_421da_row0_col7, #T_421da_row13_col14, #T_421da_row15_col12 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_421da_row0_col8, #T_421da_row1_col8, #T_421da_row2_col3, #T_421da_row13_col20, #T_421da_row14_col2, #T_421da_row29_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_421da_row0_col9, #T_421da_row20_col10, #T_421da_row23_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_421da_row0_col10, #T_421da_row22_col14, #T_421da_row26_col30 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_421da_row0_col11, #T_421da_row0_col19, #T_421da_row2_col21, #T_421da_row2_col25, #T_421da_row5_col30, #T_421da_row10_col25, #T_421da_row13_col8, #T_421da_row13_col19, #T_421da_row15_col21, #T_421da_row25_col21 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_421da_row0_col12 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_421da_row0_col13, #T_421da_row0_col15, #T_421da_row0_col25, #T_421da_row0_col26, #T_421da_row2_col29, #T_421da_row3_col20, #T_421da_row11_col0, #T_421da_row12_col4, #T_421da_row14_col11, #T_421da_row14_col27, #T_421da_row14_col30, #T_421da_row17_col8, #T_421da_row17_col19, #T_421da_row21_col22, #T_421da_row22_col21, #T_421da_row22_col27, #T_421da_row23_col28, #T_421da_row27_col24, #T_421da_row29_col2, #T_421da_row29_col23, #T_421da_row30_col1, #T_421da_row30_col3, #T_421da_row30_col5, #T_421da_row30_col6, #T_421da_row30_col7, #T_421da_row30_col9, #T_421da_row30_col10, #T_421da_row30_col12, #T_421da_row30_col14, #T_421da_row30_col16, #T_421da_row30_col17, #T_421da_row30_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_421da_row0_col14 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_421da_row0_col16, #T_421da_row13_col30, #T_421da_row15_col14, #T_421da_row15_col30, #T_421da_row25_col14 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_421da_row0_col17, #T_421da_row6_col7, #T_421da_row8_col11, #T_421da_row21_col11, #T_421da_row23_col30, #T_421da_row25_col30, #T_421da_row27_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_421da_row0_col18, #T_421da_row15_col3, #T_421da_row24_col17, #T_421da_row26_col12 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_421da_row0_col20, #T_421da_row2_col13, #T_421da_row5_col28, #T_421da_row7_col19, #T_421da_row7_col23, #T_421da_row10_col30, #T_421da_row11_col7, #T_421da_row11_col13, #T_421da_row17_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_421da_row0_col21, #T_421da_row5_col15, #T_421da_row9_col15, #T_421da_row11_col25, #T_421da_row18_col30, #T_421da_row26_col22 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_421da_row0_col22, #T_421da_row2_col19, #T_421da_row8_col17, #T_421da_row13_col9, #T_421da_row18_col6, #T_421da_row23_col9, #T_421da_row27_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_421da_row0_col23, #T_421da_row2_col12, #T_421da_row2_col22, #T_421da_row5_col25, #T_421da_row9_col25, #T_421da_row14_col22, #T_421da_row19_col15, #T_421da_row21_col0, #T_421da_row26_col25, #T_421da_row28_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_421da_row0_col24, #T_421da_row5_col20, #T_421da_row9_col26, #T_421da_row21_col24, #T_421da_row24_col26 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_421da_row0_col27, #T_421da_row1_col13, #T_421da_row2_col6, #T_421da_row3_col4, #T_421da_row4_col26, #T_421da_row5_col8, #T_421da_row6_col24, #T_421da_row8_col24, #T_421da_row10_col26, #T_421da_row14_col13, #T_421da_row14_col21, #T_421da_row17_col30, #T_421da_row18_col8, #T_421da_row20_col24, #T_421da_row20_col28, #T_421da_row28_col20 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_421da_row0_col28, #T_421da_row5_col4, #T_421da_row8_col13, #T_421da_row8_col20, #T_421da_row15_col28, #T_421da_row16_col2, #T_421da_row17_col28, #T_421da_row18_col4, #T_421da_row21_col8, #T_421da_row27_col22 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_421da_row0_col29, #T_421da_row14_col6, #T_421da_row17_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_421da_row0_col30, #T_421da_row20_col11, #T_421da_row25_col16, #T_421da_row26_col17, #T_421da_row28_col7, #T_421da_row28_col14, #T_421da_row29_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_421da_row1_col0, #T_421da_row15_col18, #T_421da_row21_col9, #T_421da_row28_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_421da_row1_col2, #T_421da_row2_col20, #T_421da_row4_col16, #T_421da_row4_col17, #T_421da_row9_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_421da_row1_col3, #T_421da_row14_col7, #T_421da_row16_col18, #T_421da_row30_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_421da_row1_col4, #T_421da_row3_col27, #T_421da_row4_col15, #T_421da_row5_col2, #T_421da_row24_col23, #T_421da_row27_col23, #T_421da_row30_col0, #T_421da_row30_col23 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_421da_row1_col5, #T_421da_row9_col7, #T_421da_row10_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_421da_row1_col6, #T_421da_row3_col29, #T_421da_row8_col9, #T_421da_row21_col27, #T_421da_row22_col9, #T_421da_row23_col21 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_421da_row1_col7, #T_421da_row5_col12 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_421da_row1_col9 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_421da_row1_col10, #T_421da_row3_col5, #T_421da_row9_col14, #T_421da_row10_col18 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_421da_row1_col11, #T_421da_row1_col27, #T_421da_row3_col25, #T_421da_row5_col22, #T_421da_row6_col19, #T_421da_row6_col28, #T_421da_row9_col2, #T_421da_row15_col22, #T_421da_row21_col28, #T_421da_row23_col25, #T_421da_row24_col25, #T_421da_row26_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_421da_row1_col12 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_421da_row1_col14 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_421da_row1_col15, #T_421da_row1_col29, #T_421da_row8_col22, #T_421da_row9_col21, #T_421da_row13_col21 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_421da_row1_col16 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_421da_row1_col17 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_421da_row1_col18, #T_421da_row2_col11, #T_421da_row6_col14 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_421da_row1_col19, #T_421da_row2_col9, #T_421da_row4_col10, #T_421da_row9_col8, #T_421da_row9_col19, #T_421da_row11_col14, #T_421da_row26_col28 {
#   background-color: #5b7ae5;
#   color: #f1f

# %% [markdown]
# # Logistic Regression

# %%
# Step 1 - modelling - split training and testing set
# Step 1: split the features and labels into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (5840, 29)

# %%
# Step 2 - define the model to be used
# Step 2: Define which model to use
model = LogisticRegression()

# %%
# Step 3: Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# /Users/urvivaidya/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Step 4: Obtain model predictions from the test data
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Step 5: Compare y_test to predictions and obtain performance metrics

# Print the classifcation report and confusion matrix
print('Classification report:\n', classification_report(y_test, y_predicted))
conf_mat = confusion_matrix(y_true=y_test, y_pred=y_predicted)
print('Confusion matrix:\n', conf_mat)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1396
#            1       0.96      0.81      0.88        64
#
#     accuracy                           0.99      1460
#    macro avg       0.98      0.91      0.94      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1394    2]
#  [  12   52]]

# %%
y_test.shape
# Out:
# (1460,)

# %%
# checking accuracy
print(f'Accuracy Score:\n{accuracy_score(y_test, y_predicted):0.3f}')
# Out:
# Accuracy Score:
# 0.990

# %% [markdown]
# # Random Forests

# %%
# Step 1 - modelling - split training and testing set
# Step 1: split the features and labels into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Step 2 - define the model to be used
# Step 2: Define which model to use
model = RandomForestClassifier()

# %%
# Step 3: Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Step 4: Obtain model predictions from the test data
y_predicted = model.predict(X_test)

# %%
# Step 5: Compare y_test to predictions and obtain performance metrics

# Print the classifcation report and confusion matrix
print('Classification report:\n', classification_report(y_test, y_predicted))
conf_mat = confusion_matrix(y_true=y_test, y_pred=y_predicted)
print('Confusion matrix:\n', conf_mat)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1403
#            1       0.98      0.82      0.90        57
#
#     accuracy                           0.99      1460
#    macro avg       0.99      0.91      0.95      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1402    1]
#  [  10   47]]

# %%
# checking accuracy
print(f'Accuracy Score:\n{accuracy_score(y_test, y_predicted):0.3f}')
# Out:
# Accuracy Score:
# 0.992

# %% [markdown]
# # Random Forests with n_estimator

# %%
# Step 2 - define the model to be used
# Step 2: Define which model to use
model = RandomForestClassifier(n_estimators = 10)

# %%
# Step 3: Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
# Step 4: Obtain model predictions from the test data
y_predicted = model.predict(X_test)

# %%
# Step 5: Compare y_test to predictions and obtain performance metrics

# Print the classifcation report and confusion matrix
print('Classification report:\n', classification_report(y_test, y_predicted))
conf_mat = confusion_matrix(y_true=y_test, y_pred=y_predicted)
print('Confusion matrix:\n', conf_mat)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1400
#            1       0.92      0.80      0.86        60
#
#     accuracy                           0.99      1460
#    macro avg       0.96      0.90      0.93      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1396    4]
#  [  12   48]]

# %%
# checking accuracy
print(f'Accuracy Score:\n{accuracy_score(y_test, y_predicted):0.3f}')

# %% [markdown]
# # Random Forests with random state

# %%
# Step 2 - define the model to be used
# Step 2: Define which model to use
model = RandomForestClassifier(n_estimators = 10, random_state=5)

# %%
# Step 3: Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=5)

# %%
# Step 4: Obtain model predictions from the test data
y_predicted = model.predict(X_test)

# %%
# Step 5: Compare y_test to predictions and obtain performance metrics

# Print the classifcation report and confusion matrix
print('Classification report:\n', classification_report(y_test, y_predicted))
conf_mat = confusion_matrix(y_true=y_test, y_pred=y_predicted)
print('Confusion matrix:\n', conf_mat)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1400
#            1       0.92      0.78      0.85        60
#
#     accuracy                           0.99      1460
#    macro avg       0.96      0.89      0.92      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1396    4]
#  [  13   47]]

# %%
# checking accuracy
print(f'Accuracy Score:\n{accuracy_score(y_test, y_predicted):0.3f}')
# Out:
# Accuracy Score:
# 0.988

# %% [markdown]
# # Funtion to use multiple models

# %%
def getModelResults(X, y, model, ts):
    
    # Step 1: splitting the set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ts)
    
    # fitting the model
    model.fit(X_train, y_train)
    
    # Step 4: Obtain model predictions from the test data
    y_predicted = model.predict(X_test)
    
    # Step 5: Compare y_test to predictions and obtain performance metrics

    # Print the classifcation report and confusion matrix
    print('Classification report:\n', classification_report(y_test, y_predicted))
    conf_mat = confusion_matrix(y_true=y_test, y_pred=y_predicted)
    print('Confusion matrix:\n', conf_mat)

# %%
# calling the function - step 2 is the input
m = RandomForestClassifier()
getModelResults(X,y,m,0.2)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1405
#            1       1.00      0.87      0.93        55
#
#     accuracy                           1.00      1460
#    macro avg       1.00      0.94      0.96      1460
# weighted avg       1.00      1.00      1.00      1460
#
# Confusion matrix:
#  [[1405    0]
#  [   7   48]]

# %%
# calling the function - step 2 is the input
m = RandomForestClassifier()
getModelResults(X,y,m,0.3)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2107
#            1       0.96      0.84      0.90        83
#
#     accuracy                           0.99      2190
#    macro avg       0.98      0.92      0.95      2190
# weighted avg       0.99      0.99      0.99      2190
#
# Confusion matrix:
#  [[2104    3]
#  [  13   70]]

# %%
# Change the model options
m = RandomForestClassifier(bootstrap=True,
class_weight={0:1, 1:12},
criterion='entropy',

max_depth=10,

min_samples_leaf=10,

n_estimators=20,
n_jobs=-1,
random_state=5)

# calling the function
getModelResults(X,y,m,0.2)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1394
#            1       0.95      0.83      0.89        66
#
#     accuracy                           0.99      1460
#    macro avg       0.97      0.92      0.94      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1391    3]
#  [  11   55]]

# %%
# Change the model options
m = RandomForestClassifier(bootstrap=True,
class_weight={0:1, 1:12},
criterion='entropy',

max_depth=10,

min_samples_leaf=10,

n_estimators=20,
n_jobs=-1,
random_state=5)

# calling the function
getModelResults(X,y,m,0.3)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2102
#            1       0.89      0.83      0.86        88
#
#     accuracy                           0.99      2190
#    macro avg       0.94      0.91      0.93      2190
# weighted avg       0.99      0.99      0.99      2190
#
# Confusion matrix:
#  [[2093    9]
#  [  15   73]]

# %%
# calling the function - step 2 is the input
m = DecisionTreeClassifier()
getModelResults(X,y,m,0.2)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1386
#            1       0.88      0.82      0.85        74
#
#     accuracy                           0.99      1460
#    macro avg       0.94      0.91      0.92      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1378    8]
#  [  13   61]]

# %%
# calling the function - step 2 is the input
m = DecisionTreeClassifier()
getModelResults(X,y,m,0.3)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2089
#            1       0.85      0.83      0.84       101
#
#     accuracy                           0.99      2190
#    macro avg       0.92      0.91      0.92      2190
# weighted avg       0.99      0.99      0.99      2190
#
# Confusion matrix:
#  [[2074   15]
#  [  17   84]]

# %%
m = LogisticRegression(max_iter = 100)
getModelResults(X,y,m,0.2)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1404
#            1       0.98      0.80      0.88        56
#
#     accuracy                           0.99      1460
#    macro avg       0.99      0.90      0.94      1460
# weighted avg       0.99      0.99      0.99      1460
#
# Confusion matrix:
#  [[1403    1]
#  [  11   45]]
# /Users/urvivaidya/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
    # We split our testing and training sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # We use the Randon Forest Classifier - optionally with variables
    model = RandomForestClassifier()
    
    # We fit the model on our data
    model.fit(X_train, y_train)
    
    # We get model predictions from the test data
    y_predicted = model.predict(X_test)
